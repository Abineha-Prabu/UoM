# %%
# !python -V
# Out:
# Python 3.12.3

# %%
import pandas as pd
df1 = pd.read_csv("scooter-1.csv")
df1.head()
# Out:
#   month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0   May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1   May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2   May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3   May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4   May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
#
#   DURATION                                start_location_name  \
# 0  0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2  0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3  0:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 4  0:03:06          401 2nd St NW, Albuquerque, NM 87102, USA
#
#                                    end_location_name   user_id  trip_ledger_id
# ...

# %%
df1.tail(2)
# Out:
#       month  trip_id  region_id  vehicle_id       started_at        ended_at  \
# 34224  July  2482275        202     3125962  7/21/2019 23:53  7/22/2019 0:05
# 34225  July  2482335        202     9449822  7/21/2019 23:55  7/22/2019 1:46
#
#       DURATION                               start_location_name  \
# 34224  0:12:00  100 Broadway Blvd SE, Albuquerque, NM 87102, USA
# 34225  1:51:00    105 Stanford Dr SE, Albuquerque, NM 87106, USA
#
#                                      end_location_name   user_id  \
# 34224       1413 4th St SW, Albuquerque, NM 87102, USA  42575656
# 34225  3339 Central Ave NE, Albuquerque, NM 87106, USA  42586810
#
#        trip_ledger_id
# 34224         2340036
# 34225         2342161

# %%
pd.set_option("display.max_columns", 500)
df1
# Out:
#       month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0       May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1       May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2       May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3       May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4       May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
# ...     ...      ...        ...         ...              ...              ...
# 34221  July  2482235        202     2893981  7/21/2019 23:51   7/22/2019 0:05
# 34222  July  2482254        202     8201542  7/21/2019 23:52   7/22/2019 0:00
# 34223  July  2482257        202     5136810  7/21/2019 23:52   7/22/2019 1:45
# 34224  July  2482275        202     3125962  7/21/2019 23:53   7/22/2019 0:05
# 34225  July  2482335        202     9449822  7/21/2019 23:55   7/22/2019 1:46
#
# ...

# %%
import pandas as pd
df2 = pd.read_csv("geocodedstreet-1.csv")
df2.head()
# Out:
#                 street           x          y  Unnamed: 3
# 0  1898 Mountain Rd NW -106.667146  35.098104         NaN
# 1  Central and Tingley -106.679271  35.091205         NaN
# 2  2550 Central Ave NE -106.617419  35.080646         NaN
# 3  2901 Central Ave NE -106.612180  35.081120         NaN
# 4   330 Tijeras Ave NW -106.390355  35.078958         NaN

# %%
df2.tail(4)
# Out:
#                street           x          y  Unnamed: 3
# 8   400 Lomas Blvd NW -106.651098  35.090928         NaN
# 9   520 Lomas Blvd NW -106.652545  35.091119         NaN
# 10                NaN         NaN        NaN         NaN
# 11                NaN         NaN        NaN         NaN

# %%
print("SCOOTER\n")
print(df1.columns)
print(df1.dtypes)
print("\nGEOCODED STREET\n")
print(df2.columns)
print(df2.dtypes)
# Out:
# SCOOTER
#
# Index(['month', 'trip_id', 'region_id', 'vehicle_id', 'started_at', 'ended_at',
#        'DURATION', 'start_location_name', 'end_location_name', 'user_id',
#        'trip_ledger_id'],
#       dtype='object')
# month                  object
# trip_id                 int64
# region_id               int64
# vehicle_id              int64
# started_at             object
# ended_at               object
# DURATION               object
# start_location_name    object
# end_location_name      object
# user_id                 int64
# trip_ledger_id          int64
# dtype: object
#
# GEOCODED STREET
#
# Index(['street', 'x', 'y', 'Unnamed: 3'], dtype='object')
# street         object
# x             float64
# y             float64
# Unnamed: 3    float64
# dtype: object

# %%
df1["DURATION"]
# Out:
# 0        0:07:03
# 1        0:04:57
# 2        0:01:14
# 3        0:06:58
# 4        0:03:06
#           ...
# 34221    0:14:00
# 34222    0:08:00
# 34223    1:53:00
# 34224    0:12:00
# 34225    1:51:00
# Name: DURATION, Length: 34226, dtype: object

# %%
df1[["trip_id", "DURATION", "start_location_name"]]
# Out:
#        trip_id DURATION                                start_location_name
# 0      1613335  0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1      1613639  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2      1613708  0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3      1613867  0:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 4      1636714  0:03:06          401 2nd St NW, Albuquerque, NM 87102, USA
# ...        ...      ...                                                ...
# 34221  2482235  0:14:00     Central @ Broadway, Albuquerque, NM 87102, USA
# 34222  2482254  0:08:00     224 Central Ave SW, Albuquerque, NM 87102, USA
# 34223  2482257  1:53:00     105 Stanford Dr SE, Albuquerque, NM 87106, USA
# 34224  2482275  0:12:00   100 Broadway Blvd SE, Albuquerque, NM 87102, USA
# 34225  2482335  1:51:00     105 Stanford Dr SE, Albuquerque, NM 87106, USA
#
# [34226 rows x 3 columns]

# %%
df1.sample(3)
# Out:
#       month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 12722  June  1875784        202     5646290   6/11/2019 1:07   6/11/2019 1:26
# 11177  June  1853210        202     3934814    6/9/2019 2:19  6/10/2019 14:39
# 1051    May  1678326        202     3481697  5/26/2019 22:44  5/26/2019 23:32
#
#        DURATION                                start_location_name  \
# 12722   0:18:22  Gold Bldg, 320 Gold Ave SW, Albuquerque, NM 87...
# 11177  36:20:13      Central @ Tingley, Albuquerque, NM 87104, USA
# 1051    0:47:59    1898 Mountain Rd NW, Albuquerque, NM 87104, USA
#
#                                      end_location_name   user_id  \
# 12722  1400 Central Ave SE, Albuquerque, NM 87106, USA  37003225
# 11177                                              NaN  38573206
# 1051   1898 Mountain Rd NW, Albuquerque, NM 87104, USA  36125291
#
#        trip_ledger_id
# 12722         1742421
# 11177         1734234
# 1051          1552129

# %%
df1[:3]
# Out:
#   month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0   May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1   May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2   May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
#
#   DURATION                                start_location_name  \
# 0  0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2  0:01:14  1 Domenici Center en Domenici Center, Albuquer...
#
#                                    end_location_name  user_id  trip_ledger_id
# 0       1899 Roma Ave NE, Albuquerque, NM 87106, USA  8417864         1488546
# 1    1111 Stanford Dr NE, Albuquerque, NM 87106, USA  8417864         1488838
# 2  1 Domenici Center en Domenici Center, Albuquer...  8417864         1488851

# %%
df1.loc[10]
# Out:
# month                                                            May
# trip_id                                                      1637075
# region_id                                                        202
# vehicle_id                                                   5192526
# started_at                                           5/24/2019 14:45
# ended_at                                             5/24/2019 14:48
# DURATION                                                     0:03:34
# start_location_name    809 Copper Ave NW, Albuquerque, NM 87102, USA
# end_location_name      809 Copper Ave NW, Albuquerque, NM 87102, USA
# user_id                                                     35466666
# trip_ledger_id                                               1511544
# Name: 10, dtype: object

# %%
df1.at[2, "DURATION"]
# Out:
# '0:01:14'

# %%
# where preserves the shape of the database
user = df.where(df["user_id"] == 8417864)
user
# Out:
#       month    trip_id  region_id  vehicle_id       started_at  \
# 0       May  1613335.0      202.0   9424537.0  5/21/2019 18:33
# 1       May  1613639.0      202.0   9424537.0  5/21/2019 19:07
# 2       May  1613708.0      202.0   9424537.0  5/21/2019 19:13
# 3       May  1613867.0      202.0   9424537.0  5/21/2019 19:29
# 4       NaN        NaN        NaN         NaN              NaN
# ...     ...        ...        ...         ...              ...
# 34221   NaN        NaN        NaN         NaN              NaN
# 34222   NaN        NaN        NaN         NaN              NaN
# 34223   NaN        NaN        NaN         NaN              NaN
# 34224   NaN        NaN        NaN         NaN              NaN
# 34225   NaN        NaN        NaN         NaN              NaN
#
#               ended_at DURATION  \
# 0      5/21/2019 18:40  0:07:03
# 1      5/21/2019 19:12  0:04:57
# 2      5/21/2019 19:15  0:01:14
# 3      5/21/2019 19:36  0:06:58
# 4                  NaN      NaN
# ...

# %%
# boolean indexing filters out rows which has FALSE values
df[(df["user_id"] == 8417864)]
# Out:
#      month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0      May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1      May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2      May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3      May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 1256   May  1681624        202     8192169   5/27/2019 1:11   5/27/2019 1:11
#
#      DURATION                                start_location_name  \
# 0     0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1     0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2     0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3     0:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 1256  0:00:12    2513 Comanche Rd NE, Albuquerque, NM 87107, USA
#
#                                       end_location_name  user_id  \
# ...

# %%
one = df["user_id"] == 8417864
two = df["trip_ledger_id"] == 1488838
df.where(one & two)
# Out:
#       month    trip_id  region_id  vehicle_id       started_at  \
# 0       NaN        NaN        NaN         NaN              NaN
# 1       May  1613639.0      202.0   9424537.0  5/21/2019 19:07
# 2       NaN        NaN        NaN         NaN              NaN
# 3       NaN        NaN        NaN         NaN              NaN
# 4       NaN        NaN        NaN         NaN              NaN
# ...     ...        ...        ...         ...              ...
# 34221   NaN        NaN        NaN         NaN              NaN
# 34222   NaN        NaN        NaN         NaN              NaN
# 34223   NaN        NaN        NaN         NaN              NaN
# 34224   NaN        NaN        NaN         NaN              NaN
# 34225   NaN        NaN        NaN         NaN              NaN
#
#               ended_at DURATION  \
# 0                  NaN      NaN
# 1      5/21/2019 19:12  0:04:57
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...

# %%
df1.describe()
# Out:
#             trip_id  region_id    vehicle_id       user_id  trip_ledger_id
# count  3.422600e+04    34226.0  3.422600e+04  3.422600e+04    3.422600e+04
# mean   2.004438e+06      202.0  5.589507e+06  3.875420e+07    1.869549e+06
# std    2.300476e+05        0.0  2.627164e+06  4.275441e+06    2.252639e+05
# min    1.613335e+06      202.0  1.034847e+06  1.080200e+04    1.488546e+06
# 25%    1.813521e+06      202.0  3.260435e+06  3.665710e+07    1.683023e+06
# 50%    1.962520e+06      202.0  5.617097e+06  3.880750e+07    1.827796e+06
# 75%    2.182324e+06      202.0  8.012871e+06  4.222774e+07    2.042524e+06
# max    2.482335e+06      202.0  9.984848e+06  4.258732e+07    2.342161e+06

# %%
df1["start_location_name"].describe()
# Out:
# count                                               34220
# unique                                               2972
# top       1898 Mountain Rd NW, Albuquerque, NM 87104, USA
# freq                                                 1210
# Name: start_location_name, dtype: object

# %%
df1["DURATION"].value_counts()
# Out:
# DURATION
# 0:04:00     825
# 0:03:00     807
# 0:05:00     728
# 0:06:00     649
# 0:07:00     627
#            ...
# 0:40:15       1
# 39:24:42      1
# 0:43:09       1
# 1:05:10       1
# 1:12:07       1
# Name: count, Length: 4135, dtype: int64

# %%
df1["end_location_name"].value_counts(dropna=False)
# Out:
# end_location_name
# NaN                                                  2070
# 1898 Mountain Rd NW, Albuquerque, NM 87104, USA       802
# Central @ Tingley, Albuquerque, NM 87104, USA         622
# 330 Tijeras Ave NW, Albuquerque, NM 87102, USA        529
# 2550 Central Ave NE, Albuquerque, NM 87106, USA       478
#                                                      ...
# 116 Washington St SE, Albuquerque, NM 87108, USA        1
# 716 Commercial St SE, Albuquerque, NM 87102, USA        1
# 119 Walter St SE, Albuquerque, NM 87102, USA            1
# 3801 Carlisle Blvd NE, Albuquerque, NM 87107, USA       1
# 1413 4th St SW, Albuquerque, NM 87102, USA              1
# Name: count, Length: 4264, dtype: int64

# %%
df1.isnull().sum()
# Out:
# month                     0
# trip_id                   0
# region_id                 0
# vehicle_id                0
# started_at                0
# ended_at                  0
# DURATION               2308
# start_location_name       6
# end_location_name      2070
# user_id                   0
# trip_ledger_id            0
# dtype: int64

# %%
df1["trip_id"].value_counts(bins=10)
# Out:
# trip_id
# (1787135.0, 1874035.0]      5561
# (1700235.0, 1787135.0]      4900
# (1874035.0, 1960935.0]      4316
# (1960935.0, 2047835.0]      3922
# (2047835.0, 2134735.0]      3296
# (2221635.0, 2308535.0]      2876
# (2308535.0, 2395435.0]      2515
# (2134735.0, 2221635.0]      2490
# (2395435.0, 2482335.0]      2228
# (1612465.999, 1700235.0]    2122
# Name: count, dtype: int64

# %%
df1.drop(columns=["region_id"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df1.drop(columns=["region_id"], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df1
# Out:
#       month  trip_id  vehicle_id       started_at         ended_at DURATION  \
# 0       May  1613335     9424537  5/21/2019 18:33  5/21/2019 18:40  0:07:03
# 1       May  1613639     9424537  5/21/2019 19:07  5/21/2019 19:12  0:04:57
# 2       May  1613708     9424537  5/21/2019 19:13  5/21/2019 19:15  0:01:14
# 3       May  1613867     9424537  5/21/2019 19:29  5/21/2019 19:36  0:06:58
# 4       May  1636714     8926493  5/24/2019 13:38  5/24/2019 13:41  0:03:06
# ...     ...      ...         ...              ...              ...      ...
# 34221  July  2482235     2893981  7/21/2019 23:51   7/22/2019 0:05  0:14:00
# 34222  July  2482254     8201542  7/21/2019 23:52   7/22/2019 0:00  0:08:00
# 34223  July  2482257     5136810  7/21/2019 23:52   7/22/2019 1:45  1:53:00
# 34224  July  2482275     3125962  7/21/2019 23:53   7/22/2019 0:05  0:12:00
# 34225  July  2482335     9449822  7/21/2019 23:55   7/22/2019 1:46  1:51:00
#
# ...

# %%
df1.drop(index=[34225], inplace=True)

# %%
df
# Out:
#       month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0       May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1       May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2       May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3       May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4       May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
# ...     ...      ...        ...         ...              ...              ...
# 34221  July  2482235        202     2893981  7/21/2019 23:51   7/22/2019 0:05
# 34222  July  2482254        202     8201542  7/21/2019 23:52   7/22/2019 0:00
# 34223  July  2482257        202     5136810  7/21/2019 23:52   7/22/2019 1:45
# 34224  July  2482275        202     3125962  7/21/2019 23:53   7/22/2019 0:05
# 34225  July  2482335        202     9449822  7/21/2019 23:55   7/22/2019 1:46
#
# ...

# %%
df1.dropna(axis=0, how="any", inplace=True)
df1
# Out:
#       month  trip_id  vehicle_id       started_at         ended_at DURATION  \
# 0       May  1613335     9424537  5/21/2019 18:33  5/21/2019 18:40  0:07:03
# 1       May  1613639     9424537  5/21/2019 19:07  5/21/2019 19:12  0:04:57
# 2       May  1613708     9424537  5/21/2019 19:13  5/21/2019 19:15  0:01:14
# 3       May  1613867     9424537  5/21/2019 19:29  5/21/2019 19:36  0:06:58
# 4       May  1636714     8926493  5/24/2019 13:38  5/24/2019 13:41  0:03:06
# ...     ...      ...         ...              ...              ...      ...
# 34220  July  2482224     7247079  7/21/2019 23:51   7/22/2019 1:46  1:55:00
# 34221  July  2482235     2893981  7/21/2019 23:51   7/22/2019 0:05  0:14:00
# 34222  July  2482254     8201542  7/21/2019 23:52   7/22/2019 0:00  0:08:00
# 34223  July  2482257     5136810  7/21/2019 23:52   7/22/2019 1:45  1:53:00
# 34224  July  2482275     3125962  7/21/2019 23:53   7/22/2019 0:05  0:12:00
#
# ...

# %%
# python drop manipulate perform computations easy but sql has contraints and relational propertues
# sql is accesing or extracting needed info but python is manipulating and changing

# %%
df1.fillna(value="00:00:00", axis="columns")
# Out:
#       month  trip_id vehicle_id       started_at         ended_at DURATION  \
# 0       May  1613335    9424537  5/21/2019 18:33  5/21/2019 18:40  0:07:03
# 1       May  1613639    9424537  5/21/2019 19:07  5/21/2019 19:12  0:04:57
# 2       May  1613708    9424537  5/21/2019 19:13  5/21/2019 19:15  0:01:14
# 3       May  1613867    9424537  5/21/2019 19:29  5/21/2019 19:36  0:06:58
# 4       May  1636714    8926493  5/24/2019 13:38  5/24/2019 13:41  0:03:06
# ...     ...      ...        ...              ...              ...      ...
# 34220  July  2482224    7247079  7/21/2019 23:51   7/22/2019 1:46  1:55:00
# 34221  July  2482235    2893981  7/21/2019 23:51   7/22/2019 0:05  0:14:00
# 34222  July  2482254    8201542  7/21/2019 23:52   7/22/2019 0:00  0:08:00
# 34223  July  2482257    5136810  7/21/2019 23:52   7/22/2019 1:45  1:53:00
# 34224  July  2482275    3125962  7/21/2019 23:53   7/22/2019 0:05  0:12:00
#
#                                      start_location_name  \
# ...

# %%
may = df1[df1["month"] == "May"]
may
# Out:
#      month  trip_id  vehicle_id       started_at         ended_at DURATION  \
# 0      May  1613335     9424537  5/21/2019 18:33  5/21/2019 18:40  0:07:03
# 1      May  1613639     9424537  5/21/2019 19:07  5/21/2019 19:12  0:04:57
# 2      May  1613708     9424537  5/21/2019 19:13  5/21/2019 19:15  0:01:14
# 3      May  1613867     9424537  5/21/2019 19:29  5/21/2019 19:36  0:06:58
# 4      May  1636714     8926493  5/24/2019 13:38  5/24/2019 13:41  0:03:06
# ...    ...      ...         ...              ...              ...      ...
# 4220   May  1737356     9974212  5/31/2019 23:58    6/1/2019 0:07  0:09:15
# 4221   May  1737376     6563620  5/31/2019 23:59  5/31/2019 23:59  0:00:23
# 4222   May  1737386     2741467  5/31/2019 23:59    6/1/2019 0:01  0:02:27
# 4223   May  1737391     6563620  5/31/2019 23:59    6/1/2019 0:02  0:03:15
# 4224   May  1737395     3099752  5/31/2019 23:59    6/1/2019 0:02  0:03:11
#
#                                     start_location_name  \
# ...

# %%
df1.drop(index=may.index, inplace=True)

# %%
df1["month"].value_counts()
# Out:
# month
# June    16832
# July     9023
# Name: count, dtype: int64

# %%
df1["month"] = df1["month"].str.upper()
df1["month"].head()
# Out:
# 4225    JUNE
# 4226    JUNE
# 4227    JUNE
# 4228    JUNE
# 4229    JUNE
# Name: month, dtype: object

# %%
for i, r in df1.head().iterrows():
    if r["trip_id"] == 1613335:
        df1.at[i, "new_column"] = "Yes"
    else:
        df.at[i, "new_column"] = "No"
df1[["trip_id", "new_column"]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[161], line 6
#       4     else:
#       5         df.at[i, "new_column"] = "No"
# ----> 6 df1[["trip_id", "new_column"]].head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
# ...
